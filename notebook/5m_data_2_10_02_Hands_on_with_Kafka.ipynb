# %% [markdown]
# # Hands-on with Kafka
#
# ![kafka](https://images.contentful.com/gt6dp23g0g38/53UO4964r0e7kRVm0mcUUZ/f6f6d7b1b90e8e88a5be0d1845bdf950/what_is_kafka_and_how_does_it_work.png)

# %% [markdown]
# ## Installing Kafka Python Client
#
# First, we'll need to install Kafka Python client `kafka-python` to consume messages from a Kafka cluster.

# %%
import json
from kafka import KafkaConsumer, TopicPartition

# %% [markdown]
# First, we'll instantiate the consumer.
#
# Our data was serialized in JSON during publishing, hence we'll need to deserialize as JSON when consuming. In actual production, it is recommended to use the binary format that we've learnt, such as Avro.

# %%
consumer = KafkaConsumer(
  bootstrap_servers=['localhost:9092'],
  auto_offset_reset='earliest',
  value_deserializer = lambda v: json.loads(v.decode('ascii')),
  key_deserializer = lambda v: json.loads(v.decode('ascii')),
)

# %% [markdown]
# We set the offset for the consumer to be `earliest` to get the earliest order (message).
#
# List the available topics:

# %%
consumer.topics()
# Out:
# {'pizza-orders'}

# %% [markdown]
# Let's assume we are the owners of a pizza delivery chain, and we'd like to push the orders to Apache Kafka as they come in.
#
# We have a topic consisting of pizza orders, which contains the Order ID, Order Details (pizzas and toppings), client's Name, Address, Phone Number, the Shop Name, Total Cost and Timestamp.
#
# There is only one partition for the topic. First, let's subscribe to the topic:

# %%
topic_name = "pizza-orders"

# %%
consumer.subscribe(topics=[topic_name])
consumer.subscription()
# Out:
# {'pizza-orders'}

# %% [markdown]
# We can then start reading the events, let's read and (pretty) print the first 5:

# %%
from pprint import pprint

# %%
for ix, message in enumerate(consumer, start=1):
    print("%d:%d: k=%s" % (message.partition,
                           message.offset,
                           message.key))
    pprint("-------------------")
    pprint(message.value)
    print()
    if ix == 5:
        break
# Out:
# 0:25: k={'shop': 'Marios Pizza'}
# '-------------------'
# {'address': '69556 Price Lodge Suite 492\nCarrollborough, NY 90674',
#  'cost': 23.09,
#  'id': 0,
#  'name': 'Katie Gonzalez',
#  'phoneNumber': '737-664-5866x4780',
#  'pizzas': [{'additionalToppings': [], 'pizzaName': 'Diavola'}],
#  'shop': 'Marios Pizza',
#  'timestamp': 1781096618341}
#
# 0:26: k={'shop': 'Its-a me! Mario Pizza!'}
# '-------------------'
# {'address': '284 Richard Green\nShannonburgh, NC 60229',
#  'cost': 33.37,
#  'id': 1,
#  'name': 'Catherine Bennett',
#  'phoneNumber': '992.736.4569x435',
#  'pizzas': [{'additionalToppings': ['🌶️ hot pepper',
#                                     '🫑 green peppers',
#                                     '🍓 strawberry'],
#              'pizzaName': 'Peperoni'},
#             {'additionalToppings': ['🍌 banana'], 'pizzaName': 'Peperoni'},
#             {'additionalToppings': ['🍌 banana', '🍓 strawberry'],
#              'pizzaName': 'Mari & Monti'}],
#  'shop': 'Its-a me! Mario Pizza!',
#  'timestamp': 1781096619343}
#
# 0:27: k={'shop': 'Circular Pi Pizzeria'}
# '-------------------'
# {'address': '4298 Schroeder Center Apt. 997\nDavisburgh, PA 07594',
#  'cost': 41.9,
#  'id': 2,
#  'name': 'Sheri Vazquez',
#  'phoneNumber': '3045362699',
#  'pizzas': [{'additionalToppings': [], 'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🧅 onion', '🥚 egg'],
#              'pizzaName': 'Peperoni'},
#             {'additionalToppings': ['🍌 banana', '🥓 bacon', '🧀 blue cheese'],
#              'pizzaName': 'Margherita'},
#             {'additionalToppings': ['🐟 tuna', '🍓 strawberry'],
#              'pizzaName': 'Marinara'}],
#  'shop': 'Circular Pi Pizzeria',
#  'timestamp': 1781096621345}
#
# 0:28: k={'shop': 'Its-a me! Mario Pizza!'}
# '-------------------'
# {'address': '0346 Joyce Pine\nOconnorview, AS 90240',
#  'cost': 28.31,
#  'id': 3,
#  'name': 'Charles Anderson',
#  'phoneNumber': '651.780.1325x6496',
#  'pizzas': [{'additionalToppings': ['🍍 pineapple', '🧅 onion', '🍌 banana'],
#              'pizzaName': 'Marinara'},
#             {'additionalToppings': ['🐟 tuna', '🧄 garlic'],
#              'pizzaName': 'Margherita'},
#             {'additionalToppings': [], 'pizzaName': 'Margherita'}],
#  'shop': 'Its-a me! Mario Pizza!',
#  'timestamp': 1781096622347}
#
# 0:29: k={'shop': 'Luigis Pizza'}
# '-------------------'
# {'address': '0603 Brandi Path\nMichaelfort, AZ 85581',
#  'cost': 46.92,
#  'id': 4,
#  'name': 'Evan Smith',
#  'phoneNumber': '485-895-7161x46815',
#  'pizzas': [{'additionalToppings': [], 'pizzaName': 'Peperoni'},
#             {'additionalToppings': [], 'pizzaName': 'Salami'},
#             {'additionalToppings': [], 'pizzaName': 'Diavola'},
#             {'additionalToppings': ['🧄 garlic'], 'pizzaName': 'Mari & Monti'}],
#  'shop': 'Luigis Pizza',
#  'timestamp': 1781096624350}

# %% [markdown]
# Now, continue printing the next 5 events, notice the offset number and order id:

# %%
for ix, message in enumerate(consumer, start=1):
    print("%d:%d: k=%s" % (message.partition,
                           message.offset,
                           message.key))
    pprint(message.value)
    print()
    if ix == 5:
        break
# Out:
# 0:5: k={'shop': 'Mammamia Pizza'}
# {'address': '144 Ross Port\nAliciafurt, KY 28535',
#  'cost': 29.56,
#  'id': 0,
#  'name': 'Ricky Sexton',
#  'phoneNumber': '8667536484',
#  'pizzas': [{'additionalToppings': ['🧅 onion', '🍍 pineapple'],
#              'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🧄 garlic'], 'pizzaName': 'Margherita'}],
#  'shop': 'Mammamia Pizza',
#  'timestamp': 1781095664473}
#
# 0:6: k={'shop': 'Ill Make You a Pizza You Cant Refuse'}
# {'address': '49595 Gary Port Suite 707\nNorth Michaelfort, CA 18853',
#  'cost': 14.03,
#  'id': 1,
#  'name': 'Russell Sanders',
#  'phoneNumber': '(873)972-6401x764',
#  'pizzas': [{'additionalToppings': ['🧀 blue cheese'], 'pizzaName': 'Peperoni'},
#             {'additionalToppings': ['🧅 onion'], 'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🫑 green peppers',
#                                     '🧅 onion',
#                                     '🍓 strawberry'],
#              'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🥚 egg', '🫑 green peppers'],
#              'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🍌 banana',
#                                     '🍓 strawberry',
#                                     '🫑 green peppers'],
#              'pizzaName': 'Diavola'}],
#  'shop': 'Ill Make You a Pizza You Cant Refuse',
#  'timestamp': 1781095666477}
#
# 0:7: k={'shop': 'Luigis Pizza'}
# {'address': '4189 Madison Glens Suite 206\nLake Vickiborough, TN 20792',
#  'cost': 11.66,
#  'id': 2,
#  'name': 'Stephanie Rivera',
#  'phoneNumber': '(544)795-9493x841',
#  'pizzas': [{'additionalToppings': [], 'pizzaName': 'Margherita'},
#             {'additionalToppings': ['🧅 onion', '🍓 strawberry'],
#              'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🍓 strawberry'],
#              'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🫑 green peppers', '🍅 tomato', '🧅 onion'],
#              'pizzaName': 'Diavola'}],
#  'shop': 'Luigis Pizza',
#  'timestamp': 1781095668478}
#
# 0:8: k={'shop': 'Marios Pizza'}
# {'address': '77289 Dustin Villages\nLake Frank, NY 99386',
#  'cost': 20.62,
#  'id': 3,
#  'name': 'Kelli Hamilton DDS',
#  'phoneNumber': '244-779-3581',
#  'pizzas': [{'additionalToppings': [], 'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': ['🍓 strawberry', '🍌 banana'],
#              'pizzaName': 'Margherita'},
#             {'additionalToppings': ['🍍 pineapple', '🍓 strawberry'],
#              'pizzaName': 'Diavola'},
#             {'additionalToppings': [], 'pizzaName': 'Marinara'}],
#  'shop': 'Marios Pizza',
#  'timestamp': 1781095669482}
#
# 0:9: k={'shop': 'Luigis Pizza'}
# {'address': '8697 Anthony Valley\nPort Kellymouth, FL 64221',
#  'cost': 8.13,
#  'id': 4,
#  'name': 'Patricia Castaneda',
#  'phoneNumber': '328-798-9970x51560',
#  'pizzas': [{'additionalToppings': ['🧅 onion'], 'pizzaName': 'Margherita'},
#             {'additionalToppings': ['🧄 garlic', '🐟 tuna'],
#              'pizzaName': 'Salami'},
#             {'additionalToppings': ['🫒 olives'], 'pizzaName': 'Salami'},
#             {'additionalToppings': ['🧀 blue cheese', '🍍 pineapple', '🧄 garlic'],
#              'pizzaName': 'Margherita'},
#             {'additionalToppings': [], 'pizzaName': 'Marinara'}],
#  'shop': 'Luigis Pizza',
#  'timestamp': 1781095671484}

# %%
# go to beginning 
consumer.seek_to_beginning()

# %%
# close consumer 
consumer.close()

# %% [markdown]
# This is the full code to publish an example order:
#
# ```python
# from kafka import KafkaProducer
#
# producer = KafkaProducer(
#   bootstrap_servers=['brave-fish-11463-us1-kafka.upstash.io:9092'],
#   sasl_mechanism='SCRAM-SHA-256',
#   security_protocol='SASL_SSL',
#   sasl_plain_username='YnJhdmUtZmlzaC0xMTQ2MyQSvwXBuLOQsV1W7YffuC8cDaZcA3fKQwakMhnQGgg',
#   sasl_plain_password='MDUxNjc4YzEtYzYxNy00NTE1LWEwNWYtMDBhODRlZmE0OGJm',
#   value_serializer=lambda v: json.dumps(v).encode('ascii'),
#   key_serializer=lambda v: json.dumps(v).encode('ascii')
# )
#
# message = {'address': '8697 Anthony Valley\nPort Kellymouth, FL 64221',
#  'id': 10,
#  'name': 'Patricia Castaneda',
#  'phoneNumber': '328-798-9970x51560',
#  'pizzas': [{'additionalToppings': ['🍅 tomato'], 'pizzaName': 'Mari & Monti'}],
#  'shop': 'Mammamia Pizza',
#  'timestamp': 1696609343719}
#
# key = {'shop': 'Mammamia Pizza'}
#
# producer.send(topic_name, key=key, value=message)
# ```
